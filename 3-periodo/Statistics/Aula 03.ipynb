# %%
import pandas as pd
import numpy as np
import requests

# %%
dados = {
    'País': ['Brail', 'Argentina', 'Argentina', 'Brasil', 'Chile', 'Chile'],
    'Ano': [2005, 2006, 2005, 2006, 2007, 2008],
    'População': [170.1, 30.5, 32.2, 172.6, 40.8, 42.0]
}

df = pd.DataFrame(dados)
df
# Out:
#     Ano       País  População
# 0  2005      Brail      170.1
# 1  2006  Argentina       30.5
# 2  2005  Argentina       32.2
# 3  2006     Brasil      172.6
# 4  2007      Chile       40.8
# 5  2008      Chile       42.0

# %%
df2 = pd.read_json('http://mobile-aceite.tcu.gov.br/mapa-da-saude/rest/emprego?quantidade=10000')
df2
# Out:
#                  bairro       cep   codPosto  \
# 0                CENTRO  62840000  2334007-0
# 1                CENTRO  63630000  2334051-7
# 2                CENTRO  63180000  2333014-7
# 3                CENTRO  63170000  2333046-5
# 4                CENTRO  62950000  2334012-6
# 5       ANTONIO BEZERRA  60356530  2333070-8
# 6                CENTRO  60060390  2333068-6
# 7                CENTRO  63600000  2333066-0
# 8             MESSEJANA  60840045  2333013-9
# 9                CENTRO  61940145  2333021-0
# 10               CENTRO  62220000  2334014-2
# 11       PARQUE GENIBAU  60534130  2333036-8
# 12               CENTRO  62350000  2334047-9
# 13          NOVA RUSSAS  62200000  2334035-5
# 14               CENTRO  63590000  2334004-5
# 15              PIRAMBU  60310690  2333053-8
# 16              ALDEOTA  60135310  2333055-4
# 17             MEIRELES  60115000  2333052-0
# 18               CENTRO  63800000  2333045-7
# 19        EDSON QUEIROZ  60811340  2333031-7
# ...

# %%
df3 = pd.read_csv('https://raw.githubusercontent.com/nybbles/kaggle/master/train.csv')
df3
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# 6           0       1                            McCarthy, Mr. Timothy J
# 7           0       3                     Palsson, Master. Gosta Leonard
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# ...

# %%
df3[['age', 'name']]
# Out:
#       age                                               name
# 0    22.0                            Braund, Mr. Owen Harris
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    26.0                             Heikkinen, Miss. Laina
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4    35.0                           Allen, Mr. William Henry
# 5     NaN                                   Moran, Mr. James
# 6    54.0                            McCarthy, Mr. Timothy J
# 7     2.0                     Palsson, Master. Gosta Leonard
# 8    27.0  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9    14.0                Nasser, Mrs. Nicholas (Adele Achem)
# 10    4.0                    Sandstrom, Miss. Marguerite Rut
# 11   58.0                           Bonnell, Miss. Elizabeth
# 12   20.0                     Saundercock, Mr. William Henry
# 13   39.0                        Andersson, Mr. Anders Johan
# ...

# %%
df3.loc[2:20]
# Out:
#     survived  pclass                                               name  \
# 2          1       3                             Heikkinen, Miss. Laina
# 3          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0       3                           Allen, Mr. William Henry
# 5          0       3                                   Moran, Mr. James
# 6          0       1                            McCarthy, Mr. Timothy J
# 7          0       3                     Palsson, Master. Gosta Leonard
# 8          1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9          1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10         1       3                    Sandstrom, Miss. Marguerite Rut
# 11         1       1                           Bonnell, Miss. Elizabeth
# 12         0       3                     Saundercock, Mr. William Henry
# 13         0       3                        Andersson, Mr. Anders Johan
# ...

# %%
df3.head(10)
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# ...

# %%
filtro = df3[df3.sex == 'male']
filtro = filtro[filtro.survived == 1]
filtro = filtro[filtro.pclass == 3]
filtro
# Out:
#      survived  pclass                                               name  \
# 36          1       3                                   Mamee, Mr. Hanna
# 65          1       3                           Moubarek, Master. Gerios
# 74          1       3                                      Bing, Mr. Lee
# 81          1       3                        Sheerlinck, Mr. Jan Baptist
# 107         1       3                             Moss, Mr. Albert Johan
# 125         1       3                       Nicola-Yarred, Master. Elias
# 127         1       3                          Madsen, Mr. Fridtjof Arne
# 146         1       3       Andersson, Mr. August Edvard ("Wennerstrom")
# 165         1       3    Goldsmith, Master. Frank John William "Frankie"
# 204         1       3                           Cohen, Mr. Gurshon "Gus"
# 207         1       3                        Albimona, Mr. Nassef Cassem
# 220         1       3                     Sunderland, Mr. Victor Francis
# ...

# %%
filtro = df3[(df3.sex == 'male') & (df3.survived == 1) & (df3.pclass == 3)]
filtro
# Out:
#      survived  pclass                                               name  \
# 36          1       3                                   Mamee, Mr. Hanna
# 65          1       3                           Moubarek, Master. Gerios
# 74          1       3                                      Bing, Mr. Lee
# 81          1       3                        Sheerlinck, Mr. Jan Baptist
# 107         1       3                             Moss, Mr. Albert Johan
# 125         1       3                       Nicola-Yarred, Master. Elias
# 127         1       3                          Madsen, Mr. Fridtjof Arne
# 146         1       3       Andersson, Mr. August Edvard ("Wennerstrom")
# 165         1       3    Goldsmith, Master. Frank John William "Frankie"
# 204         1       3                           Cohen, Mr. Gurshon "Gus"
# 207         1       3                        Albimona, Mr. Nassef Cassem
# 220         1       3                     Sunderland, Mr. Victor Francis
# ...

# %%
filtro.shape
# Out:
# (47, 11)
