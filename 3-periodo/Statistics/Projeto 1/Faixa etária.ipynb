# %% [markdown]
# #### Ficha corrida do detento - faixa etária

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
etaria = pd.read_csv('./Faixa-etaria.csv')
etaria
# Out:
#                      18 a 24 anos  25 a 29 anos  30 a 34 anos  35 a 45 anos  \
# Acre                           45            25            14            13
# Alagoas                        29            31            18            15
# Amapá                          36            24            18            18
# Amazonas                       40            24            17            15
# Bahia                          38            23            17            16
# Ceará                          32            24            18            18
# Distrito Federal               29            24            19            21
# Espírito Santo                 39            25            15            15
# Goiás                          30            30            20            13
# Maranhão                       32            27            21            14
# Mato Grosso                    26            29            19            18
# ...

# %%
etaria['18 a 24 anos'].plot.bar(figsize=(15,10))

# %%
etaria['25 a 29 anos'].plot.bar(figsize=(15,10))

# %%
etaria['30 a 34 anos'].plot.bar(figsize=(15,10))
