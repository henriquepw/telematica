# %% [markdown]
# **Mapa de violência- Henrique**
#
#     - https://www.mapadaviolencia.org.br/
#     - http://dapp.fgv.br/seguranca-e-cidadania/datacrime/#downloads

# %% [markdown]
# ## Tema escolhido: Estatísticas prisionais
# ### [Link original pra download](http://dapp.fgv.br/seguranca-e-cidadania/datacrime/dados/carcere.xlsx)]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Sob o controle do Estado - Retratos do sistema carcerário em 2016

# %%
retratro = pd.read_csv('./Retratos-do-sistema-carcerario-2016.csv')
retratro
# Out:
#                                   Taxa
# Sistema Penitenciário Federal  437.000
# Secretarias de Segurança        36.765
# Taxa de Ocupação(%)            197.400
# Estrangeiros presos              2.606
# Pessoas com deficiência          4.167

# %% [markdown]
# #### O xadrez do cárcere - Série histórica

# %%
xadrez = pd.read_csv('./O-xadrez-do-carcere.csv')
xadrez
# Out:
#        Presos    Vagas  Déficite
# 2000  232.755  135.710    97.045
# 2001  233.859  141.297    92.562
# 2002  239.345  156.432    82.913
# 2003  308.304  179.489   128.815
# 2004  336.358  200.417   135.941
# 2005  361.402  206.559   154.843
# 2006  401.236  236.148   165.088
# 2007  422.373  249.515   172.858
# 2008  451.429  266.946   184.483
# 2009  473.626  278.726   194.900
# 2010  496.251  281.520   214.731
# 2011  514.582  295.413   219.169
# 2012  549.786  310.687   239.099
# 2013  581.507  341.253   240.254
# 2014  622.202  371.884   250.318
# 2015  698.618  371.201   327.417
# 2016  726.712  368.049   358.663

# %% [markdown]
# #### Cartografia Prisional - o q ser?

# %%
Cartografia = pd.read_csv('./Cartografia-prisional.csv')
Cartografia
# Out:
#                       Taxa  Taxa (%)
# Brasil               352.6      40.2
# Acre                 656.8      37.1
# Alagoas              207.1      37.2
# Amapá                342.6      23.4
# Amazonas             284.6      64.4
# Bahia                100.1      58.2
# Ceará                385.6      65.8
# Distrito Federal     510.3      24.0
# Espírito Santo       488.5      42.3
# Goiás                252.6      40.4
# Maranhão             127.0      58.6
# Mato Grosso          313.5      52.5
# Mato Grosso do Sul   696.7      32.4
# Minas Gerais         325.5      57.8
# Pará                 171.8      48.3
# Paraíba              284.5      42.2
# Paraná               459.9      28.4
# Pernambuco           367.2      50.8
# Piauí                125.6      55.0
# Rio de Janeiro       301.9      40.1
# Rio Grande do Norte  253.5      33.7
# Rio Grande do Sul    300.1      37.7
# Rondônia             606.1      17.3
# Roraima              454.9      44.2
# ...

# %%
Cartografia.plot.pie(y='Taxa', figsize=(10, 10))

# %% [markdown]
# #### A causa da exclusão

# %%
exclusao = pd.read_csv('./A-causa-da-exclusao.csv')
exclusao
# Out:
#                           Total  Mulheres  Homens
# Tráfico de drogas            28        62      26
# Roubo                        25        11      26
# Furto                        12         9      12
# Homicídio                    11         6      11
# Outros                       11         6      11
# Estatuto do desarmamento      5         2       5
# Receptação                    3         1       3
# Latrocínio                    3         1       3
# Quadrilha ou bando            2         2       2
# Violência doméstica           1         0       1

# %% [markdown]
# #### Ficha corrida do detento - faixa etária

# %%
etaria = pd.read_csv('./Faixa-etaria.csv')
etaria
# Out:
#                      18 a 24 anos  25 a 29 anos  30 a 34 anos  35 a 45 anos  \
# Acre                           45            25            14            13
# Alagoas                        29            31            18            15
# Amapá                          36            24            18            18
# Amazonas                       40            24            17            15
# Bahia                          38            23            17            16
# Ceará                          32            24            18            18
# Distrito Federal               29            24            19            21
# Espírito Santo                 39            25            15            15
# Goiás                          30            30            20            13
# Maranhão                       32            27            21            14
# Mato Grosso                    26            29            19            18
# ...

# %% [markdown]
# #### Ficha corrida do detento - grau de instrução

# %%
grau = pd.read_csv('./Grau-de-Instrucao.csv')
grau
# Out:
#                      Analfabeto  Alfabetizado (sem cursos regulares)  \
# Acre                          6                                    6
# Alagoas                      23                                   11
# Amapá                         2                                    3
# Amazonas                      1                                    1
# Bahia                        10                                   15
# Ceará                         7                                   27
# Distrito Federal              2                                    1
# Espírito Santo                3                                    6
# Goiás                         7                                   16
# Maranhão                     13                                   16
# Mato Grosso                   6                                    9
# Mato Grosso do Sul            2                                    4
# Minas Gerais                  3                                    7
# ...

# %% [markdown]
# #### Ficha corrida do detento - por raça/cor

# %%
cor = pd.read_csv('./Raca-Cor.csv')
cor
# Out:
#                      Branca  Negra  Amarela  Indígena  Outras  \
# Acre                      5     95        0         0       0
# Alagoas                  20     80        0         0       0
# Amapá                     9     91        1         0       0
# Amazonas                 16     84        0         0       1
# Bahia                    11     89        0         0       0
# Ceará                    15     84        1         0       0
# Distrito Federal         17     82        1         0       0
# Espírito Santo           19     78        3         0       0
# Goiás                    21     79        0         0       0
# Maranhão                 15     84        1         0       0
# Mato Grosso              26     74        0         0       0
# Mato Grosso do Sul       35     62        0         1       1
# Minas Gerais             28     71        2         0       0
# Pará                     14     83        2         0       1
# ...
