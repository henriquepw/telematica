# %% [markdown]
# #### A causa da exclusão

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
exclusao = pd.read_csv('./A-causa-da-exclusao.csv')
exclusao
# Out:
#                           Total  Mulheres  Homens
# Tráfico de drogas            28        62      26
# Roubo                        25        11      26
# Furto                        12         9      12
# Homicídio                    11         6      11
# Outros                       11         6      11
# Estatuto do desarmamento      5         2       5
# Receptação                    3         1       3
# Latrocínio                    3         1       3
# Quadrilha ou bando            2         2       2
# Violência doméstica           1         0       1

# %%
exclusao['Total'].plot.barh(figsize=(18,10))

# %%
exclusao.plot.box(figsize=(15,10))
